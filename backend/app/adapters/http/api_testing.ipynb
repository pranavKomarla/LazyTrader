# %%
import sys
import os

# Add the backend directory to Python path so we can import from app
backend_path = os.path.abspath('../../..')  # Go up 3 levels from current notebook location
if backend_path not in sys.path:
    sys.path.append(backend_path)

print(f"Added to Python path: {backend_path}")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Added to Python path: /Users/pranavkomarla/Desktop/MLOPS/LLM Project/backend
# Current working directory: /Users/pranavkomarla/Desktop/MLOPS/LLM Project/backend/app/adapters/http

# %%
# Now we can import from our app package
from app.core.config import config

FINNHUB_API_KEY = config.FINNHUB_API_KEY
NEWS_API_KEY = config.NEWS_API_KEY

print(f"FINNHUB_API_KEY: {FINNHUB_API_KEY}")
print(f"NEWS_API_KEY: {NEWS_API_KEY}")
# Out:
# /Users/pranavkomarla/Desktop/MLOPS/LLM Project/backend
# mongodb://admin:password@localhost:27017/stockapp?authSource=admin
# appdb
# cqjvae1r01qnn2b34jqgcqjvae1r01qnn2b34jr0
# 29a197f086764edb825ab8c0b6d9ffb2
# l9cwj3CDJxQWjeP0WmpgH8P8MCEgFC_5
# FINNHUB_API_KEY: cqjvae1r01qnn2b34jqgcqjvae1r01qnn2b34jr0
# NEWS_API_KEY: 29a197f086764edb825ab8c0b6d9ffb2

# %%
# Finnhub API Testing/General News API Call
import finnhub
finnhub_client = finnhub.Client(api_key=FINNHUB_API_KEY) # Use limit to control number of news articles returned

print(finnhub_client.general_news('general', min_id=0))
# Out:
# [{'category': 'top news', 'datetime': 1757114298, 'headline': 'Senate seeks to rein in stock tokenization in latest crypto bill draft', 'id': 7513400, 'image': 'https://image.cnbcfm.com/api/v1/image/108140160-1746208763777-gettyimages-2201505903-lummis_BC_194_022625JPG.jpeg?v=1757112547&w=1920&h=1080', 'related': '', 'source': 'CNBC', 'summary': 'Crypto companies like Coinbase and Ripple are pushing for the passage of a market structure bill.', 'url': 'https://www.cnbc.com/2025/09/05/senate-stock-tokenization-crypto-bill.html'}, {'category': 'top news', 'datetime': 1757113262, 'headline': "Cramer's week ahead: New economic data and Apple's latest iPhone", 'id': 7513397, 'image': 'https://image.cnbcfm.com/api/v1/image/107076310-1655341006752-IMG_1949rbbb.jpg?v=1697582097&w=1920&h=1080', 'related': '', 'source': 'CNBC', 'summary': "CNBC's Jim Cramer on Friday walked investors through next week on Wall Street.", 'url': 'https://www.cnbc.com/2025/09/05/cramers-week-ahead-new-economic-data-and-apples-latest-iphone.html'}, {'category': 'top news', 'datetime': 1757108220, 'headline': 'Kenvue fights back against Tylenol safety concerns as its stock tumbles', 'id': 7513383, 'image': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/market_watch_logo.png', 'related': '', 'source': 'MarketWatch', 'summary': 'Kenvue rushed to the defense of Tylenol, but the stock still suffered a record selloff on news that RFK Jr. will release a report linking the use of acetaminophen during pregnancy to autism.', 'url': 'https://www.marketwatch.com/story/kenvue-fights-back-against-tylenol-safety-concerns-as-its-stock-tumbles-236cdbe1'}, {'category': 'top news', 'datetime': 1757108160, 'headline': 'How you can still get a refund for a delayed or canceled flight even as Trump scraps Biden’s airline compensation proposal', 'id': 7513384, 'image': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/market_watch_logo.png', 'related': '', 'source': 'MarketWatch', 'summary': 'The Trump administration this week said it will reverse plans to require airlines to compensate passengers for lengthy delays and cancellations, a move consumer advocates say is likely the first of many to weaken protections for travelers.', 'url': 'https://www.marketwatch.com/story/how-you-can-still-get-a-refund-for-a-delayed-or-canceled-flight-even-as-trump-scraps-bidens-airline-compensation-proposal-38b28011'}, {'category': 'top news', 'datetime': 1757104200, 'headline': 'OPEC+ meets this weekend at a precarious time for crude oil. Here’s what’s at stake.', 'id': 7513374, 'image': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/market_watch_logo.png', 'related': '', 'source': 'MarketWatch', 'summary': 'The market has a lot to contend with as OPEC+ considers a second round of production hikes this weekend, against an economic and geopolitical backdrop that’s dimmed prospects for demand and boosted the potential for a supply surplus this year and next.', 'url': 'https://www.marketwatch.com/story/opec-meets-this-weekend-at-a-precarious-time-for-crude-oil-heres-whats-at-stake-a8379d98'}, {'category': 'top news', 'datetime': 1757101740, 'headline': 'Why AMD’s stock is seeing one of the worst drops in the S&P 500 today', 'id': 7513332, 'image': 'https://static2.finnhub.io/file/publicdatany/finnhubimage/market_watch_logo.png', 'related': '', 'source': 'MarketWatch', 'summary': 'AMD offers a GPU alternative to Nvidia, but it seems like hyperscalers are paying more attention to custom chips made by Broadcom.', 'url': 'https://www.marketwatch.com/story/why-amds-stock-is-seeing-one-of-the-worst-drops-in-the-s-p-500-today-55cded85'}, {'category': 'top news', 'datetime': 1757100524, 'headline': "Mystery of former Federal Reserve Governor Kugler's resignation deepens as real estate records raise new questions", 'id': 7513327, 'image': 'https://image.cnbcfm.com/api/v1/image/108195070-1757098521007-gettyimages-2221380036-FEDERAL_RESERVE.jpeg?v=1757098542&w=1920&h=1080', 'rel ...

# %%
# Finnhub API Testing/Company News API Call
print(finnhub_client.company_news('AAPL', _from='2025-09-01', to='2025-09-05')) # Use limit to control number of news articles returned
# Out:
# [{'category': 'company', 'datetime': 1757085822, 'headline': 'Stock Market Hits New Highs On Google, Broadcom, Jobs Report: Weekly Review', 'id': 136648832, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'AAPL', 'source': 'Yahoo', 'summary': 'The Dow Jones, S&P 500 and Nasdaq hit record highs Friday, buoyed by Google, Broadcom and the monthly jobs report.', 'url': 'https://finnhub.io/api/news?id=da0577ce2a0192db630e5acca2bca7493c8fe8e9f6e0fc4776695fb10159b2e6'}, {'category': 'company', 'datetime': 1757084913, 'headline': 'Apple Inc. (AAPL): China’s The “Wildcard,” Says Jim Cramer', 'id': 136648823, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'AAPL', 'source': 'Yahoo', 'summary': 'We recently published 10 Stocks That Were On Jim Cramer’s Radar As He Warned “It’s Too Early” To Buy. Apple Inc. (NASDAQ:AAPL) is one of the stocks Jim Cramer recently discussed. Apple Inc. (NASDAQ:AAPL)’s shares jumped by 3.3% on Wednesday after a major headwind disappeared in the form of search engine giant Google’s troubles with the […]', 'url': 'https://finnhub.io/api/news?id=3135e781bea8a73b373bedc24edd1a01f9d8e3d10dc9d70a5fbf73fd0ea2d24a'}, {'category': 'company', 'datetime': 1757070602, 'headline': 'Alphabet Within Striking Range of $3 Trillion as Key Risk Clears', 'id': 136647722, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'AAPL', 'source': 'Yahoo', 'summary': 'The decision by a US district court judge Tuesday enabled Google’s parent to avoid the most punitive measures sought by regulators, including the sale of its Chrome browser.  With the case now out of the way, investors are turning their attention back to the potential for gains in Alphabet’s stock, which is the cheapest among the Magnificent Seven despite the recent rally.  “What it does is it clears the runway for additional growth opportunities,” said Neville Javeri, senior fund manager at Allspring Global Investments, referring to the ruling.', 'url': 'https://finnhub.io/api/news?id=f6312e99feb4eacfaed1b824f608e17b1138f3574025da4be27dcd6b2b9c2868'}, {'category': 'company', 'datetime': 1757082920, 'headline': 'Apple upgraded, AMD downgraded: Wall Street’s top analyst calls', 'id': 136648835, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'AAPL', 'source': 'Yahoo', 'summary': 'The most talked about and market moving research calls around Wall Street are now in one place. Here are today’s research calls that investors need to know, as compiled by The Fly. Top Upgrades: MoffettNathanson upgraded Apple (AAPL) to Neutral from Sell with a $225 price target. A number of key headwinds have faded and the “worst-case scenarios are off the table,” the firm tells investors. Evercore ISI upgraded Brinker (EAT) to Outperform from In Line with a price target of $210, up from $190.', 'url': 'https://finnhub.io/api/news?id=615f13692544b57246021e24ca8b2eeceeb890965218b26c23dc3548d85e2fed'}, {'category': 'company', 'datetime': 1757082649, 'headline': 'Apple: Sell While Ahead - Weak AI And Mature Markets Signal Caution', 'id': 136650050, 'image': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/458990823/image_458990823.jpg?io=getty-c-w1536', 'related': 'AAPL', 'source': 'SeekingAlpha', 'summary': "Apple Inc.'s high valuation faces scrutiny as AI growth lags and Warren Buffett trims his stake. Click for my updated look at AAPL and why I am bearish.", 'url': 'https://finnhub.io/api/news?id=966616dec9d8c8b60880c0c16b0a5c98876d678ab86382409bc6c4dbbcb9a958'}, {'category': 'company', 'datetime': 1757082000, 'headline': 'BYOD and Enterprise Mobility Market Growth Opportunities and Competitive Strategies (2025-2034) Featuring Microsoft, Cisco, Blackberry, Infosys, IBM and More', 'id': 136648830, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'AAPL', 'source': 'Yahoo', 'summary ...

# %%
# News API Testing

from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key=NEWS_API_KEY)

# Fetch top headlines
top_headlines = newsapi.get_top_headlines(sources='bbc-news')
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Rubio says US will 'blow up' foreign crime groups if needed", 'description': 'The secretary of state made the comments during a trip to Ecuador, where he announced new measures targeting criminal gangs.', 'url': 'https://www.bbc.co.uk/news/articles/cx23nzwjnwwo', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/7293/live/6cc45d20-89cb-11f0-9955-fd3f4ebf7708.jpg', 'publishedAt': '2025-09-05T02:07:19.3413249Z', 'content': 'Asked whether smugglers coming from US allies, like Mexico and Ecuador, could face "unilateral execution" from US forces, Rubio said "co-operative governments" would help identify smugglers.\r\n"The pr… [+2678 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Sir John Curtice: How Reform's capture of the Brexit vote could be enough to win an election", 'description': 'The party has now been ahead in the polls for five months, but can it keep the momentum?', 'url': 'https://www.bbc.co.uk/news/articles/cwy853rj2kzo', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/030f/live/1143f090-898b-11f0-9cf6-cbf3e73ce2b9.png', 'publishedAt': '2025-09-05T00:37:21.4986374Z', 'content': 'There is one other potential obstacle facing Reform. The party is currently benefiting from a fragmentation of support among its rivals.\r\nWe have heard lots about Labour and the Conservatives both lo… [+895 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Newspaper headlines: Rayner's 'judgement day' and 'Dorries joins Tories'", 'description': "The fallout from Angela Rayner's stamp duty admission continues to dominate Friday's papers.", 'url': 'https://www.bbc.co.uk/news/articles/cn4w9541290o', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/fe36/live/8094cb40-89e0-11f0-9cf6-cbf3e73ce2b9.jpg', 'publishedAt': '2025-09-05T00:37:14.0606144Z', 'content': "Image caption, Labour MPs are urging the PM not to meet the Israeli President Isaac Herzog during his planned trip to London next week, the Guardian says. The paper reports Herzog's visit comes at a … [+254 chars]"}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "David Bowie's final project was a musical set in London", 'description': 'Shortly before his death, the star wrote dozens of notes for a musical set in 18th Century London.', 'url': 'https://www.bbc.co.uk/news/articles/c3dpdpvj083o', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/d8a3/live/8feb5b90-89a9-11f0-9f0a-494169926e61.jpg', 'publishedAt': '2025-09-04T23:52:27.6067857Z', 'content': 'Bowie was particularly fascinated by crime and punishment. \r\nIn one note, he envisaged the aftermath of a public hanging, with "surgeons fighting over corpses".\r\nHe also considered making Jack Sheppa… [+906 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Lawyer of jailed Teesside teen Bella Culley criticises embassy', 'description': 'Bella Culley is in prison in Georgia waiting to see if enough money can be raised for her release.', 'url': 'https://www.bbc.co.uk/news/articles/cvg43xxerlvo', 'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/d1d2/live/537714a0-30cc-11f0-b5da-71555b1343d7.png', 'publishedAt': '2025-09-04T23:37:21.2473698Z', 'content': 'The lawyer of a British teenager accused of drug smuggling and held in prison in Georgia, South Caucasus, has accused the British embassy of not doing enough to help her.\r\nBella Culley, from Billingh… [+446 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'At least 55,000 people face new tests in diabetes error', 'description': 'Errors by diabetes analysis machines mean at least 55,000 people in England will need further hospital tests.', 'url' ...
